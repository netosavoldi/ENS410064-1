# %% [markdown]
# # Atividade 3
# ## Análise de um raster

# %%
import xarray as xr
import rioxarray as rxr
import rasterio
from affine import Affine

# %%
path=(r"C:\Users\Windows 10\Downloads\brasil_coverage_2022.tif")
dataset = rasterio.open(path)
dataraster = rxr.open_rasterio(path)
dataraster
# Out:
# <xarray.DataArray (band: 1, y: 158459, x: 155239)>
# [24599016701 values with dtype=uint8]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -74.9 -74.9 -74.9 -74.9 ... -33.06 -33.06 -33.06
#   * y            (y) float64 7.912 7.912 7.911 7.911 ... -34.79 -34.79 -34.79
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
